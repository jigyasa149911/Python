# %%
import numpy as np
import pandas as pd

# %%
# Creating series in Pandas
df=pd.Series([1,2,3,4,5])
df
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# Creating Dataframes in pandas
df=pd.DataFrame({"serial no:":[1,2,3,4,5],
               "Roll no:":[23,12,34,8,10],
               "Grade":['A','B','A','B','C'],
               "Class":['XII','XI','X','XII','X']})
df
# Out:
#    serial no:  Roll no: Grade Class
# 0           1        23     A   XII
# 1           2        12     B    XI
# 2           3        34     A     X
# 3           4         8     B   XII
# 4           5        10     C     X

# %%
# Imporing Data
# text and csv data can be imported bt=y using pd.read_csv() and excel data can be imported by pd.read_excel()
df1=pd.read_csv('carsdata.csv',delimiter='\t')

# %%
# To create a column
df2=pd.read_csv('nba')
df2['Total']=df.iloc[:,:].sum(axis=1)  
df2.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary       Total
# 0              Texas  7730337.0  15461084.0
# 1          Marquette  6796117.0  13592952.0
# 2  Boston University        NaN       524.0
# 3      Georgia State  1148640.0   2297750.0
# 4                NaN  5000000.0  10000536.0

# %%
# To delete a column use df.drop(col. name)
df.drop(columns=['Total']).head()  #To delete a column.
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df1.head() #df.head(n) gives first n data from dataframe where 5 is default value for n.
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
df1.tail() #df.tail(n) gives last n data from dataframe ehere 5 is default value for n.
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %%
df1.columns #returns all colums of the dataframe
df1['body-style'] # returns all the rows of column 'body-style'.
df1.company # returns all the rows of column 'company'.
df1['body-style'][0:5] #returns rows of specified indices of body-style column.
df1[['body-style','company']] # returns all rows of specified multiple columns.
df1[['body-style','company']][0:5] #returns rows of specified indices of multiple columns.
# Out:
#     body-style      company
# 0  convertible  alfa-romero
# 1  convertible  alfa-romero
# 2    hatchback  alfa-romero
# 3        sedan         audi
# 4        sedan         audi

# %%
#sort_values()
df1.sort_values('horsepower',axis=0,ascending=True,inplace=True,kind='quicksort') 
# the df will be sorted according to horsepower in ascending order.
df1.head(10)
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 13     16   chevrolet  hatchback        88.4   141.1           l
# 55     80  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 40     53      nissan      sedan        94.5   165.3         ohc
# 49     67      toyota  hatchback        95.7   158.7         ohc
# 51     69      toyota      wagon        95.7   169.7         ohc
# 50     68      toyota  hatchback        95.7   158.7         ohc
# 53     71      toyota      wagon        95.7   169.7         ohc
# 48     66      toyota  hatchback        95.7   158.7         ohc
# 52     70      toyota      wagon        95.7   169.7         ohc
#
#    num-of-cylinders  horsepower  average-mileage   price
# 13            three          48               47  5151.0
# 55             four          52               37  7775.0
# 57             four          52               37  7995.0
# ...

# %%
# sort_index()
df1.sort_index(axis=0,ascending=True,inplace=True,kind='quicksort')
df1.head(10)
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
# 5      5         audi        sedan        99.8   177.3         ohc
# 6      6         audi        wagon       105.8   192.7         ohc
# 7      9          bmw        sedan       101.2   176.8         ohc
# 8     10          bmw        sedan       101.2   176.8         ohc
# 9     11          bmw        sedan       101.2   176.8         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# ...

# %%
df=pd.DataFrame({
    "A":[1,2,3,4,5],
    "B":[6,7,1,3,1],
    "C":[9,3,6,1,3]
})
df.idxmax(axis=0)  # returns the index of largest element in each row.
# Out:
# A    4
# B    1
# C    0
# dtype: int64

# %%
df=pd.DataFrame({
    "A":[1,2,3,4,5],
    "B":[6,7,1,3,1],
    "C":[9,3,6,1,3]
})
df.idxmax(axis=1)  # returns the index of largest element in each column and column name.
# Out:
# 0    C
# 1    B
# 2    C
# 3    A
# 4    A
# dtype: object

# %%
df=pd.DataFrame({
    "A":[1,2,3,4,5],
    "B":[6,7,1,3,1],
    "C":[9,3,6,1,3]
})
df.idxmin(axis=0)  # returns the index of smallest element in each row.
# Out:
# A    0
# B    2
# C    3
# dtype: int64

# %%
df=pd.DataFrame({
    "A":[1,2,3,4,5],
    "B":[6,7,1,3,1],
    "C":[9,3,6,1,3]
})
df.idxmin(axis=1)  # returns the index of smallest element in each column with column name.
# Out:
# 0    A
# 1    A
# 2    B
# 3    C
# 4    B
# dtype: object

# %%
# df.loc()
df.index=['Row1','Row2','Row3','Row4','Row5']  # creates the index of each row.
df.loc['Row2','A']  # access a particular item in the given column i.e. A here at Row2
# Out:
# 2

# %%
# df.iloc[]
df1.iloc[1:7]  # accesses multiple rows and columns as per given indices.
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
# 5      5         audi        sedan        99.8   177.3         ohc
# 6      6         audi        wagon       105.8   192.7         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0
# 5             five         110               19  15250.0
# 6             five         110               19  18920.0

# %%
# df.fillna()
df2=pd.read_csv('nba')
df2['College'].fillna('No College info. available',inplace=True)  # fill Nan values with the info given insode fillna()
df2['Age'].fillna(method='ffill',inplace=True) #ffill method fills the nan value with value before it.
df2
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
# value_counts()
idx=pd.Index(['Rahul','Simona','Vaibhav',"Amit",'Amit','Rahul','Aastha','Aastha']) 
idx.value_counts()  # counts the occurence of a particular value in index.
# Out:
# Amit       2
# Aastha     2
# Rahul      2
# Vaibhav    1
# Simona     1
# dtype: int64

# %%
# groupby()
df2.groupby(['Team']).mean().head()
# Out:
#                       Number        Age      Weight        Salary  \
# Team
# Atlanta Hawks      19.000000  28.200000  221.266667  4.860197e+06
# Boston Celtics     31.866667  24.733333  219.466667  4.181505e+06
# Brooklyn Nets      18.266667  25.600000  215.600000  3.501898e+06
# Charlotte Hornets  17.133333  26.133333  220.400000  5.222728e+06
# Chicago Bulls      19.200000  27.400000  218.933333  5.785559e+06
#
#                           Total
# Team
# Atlanta Hawks      9.720930e+06
# Boston Celtics     7.806028e+06
# Brooklyn Nets      7.004316e+06
# Charlotte Hornets  1.044598e+07
# Chicago Bulls      1.157165e+07

# %%
df2.groupby(['Team']).mean().sort_values('Salary',ascending=False).head()
# Out:
#                           Number        Age      Weight        Salary  \
# Team
# Cleveland Cavaliers    14.466667  29.533333  227.866667  7.642049e+06
# Miami Heat             10.466667  28.933333  218.400000  6.347359e+06
# Los Angeles Clippers   19.533333  29.466667  219.733333  6.323643e+06
# Oklahoma City Thunder  14.000000  27.066667  229.400000  6.251020e+06
# Golden State Warriors  20.866667  27.666667  224.600000  5.924600e+06
#
#                               Total
# Team
# Cleveland Cavaliers    7.132851e+06
# Miami Heat             5.501303e+06
# Los Angeles Clippers   6.323911e+06
# Oklahoma City Thunder  6.251290e+06
# Golden State Warriors  5.924873e+06

# %%
df2.groupby(['Team']).sum().head()
# Out:
#                    Number    Age  Weight      Salary        Total
# Team
# Atlanta Hawks       285.0  423.0  3319.0  72902950.0  145813954.0
# Boston Celtics      478.0  371.0  3292.0  58541068.0  117090418.0
# Brooklyn Nets       274.0  384.0  3234.0  52528475.0  105064734.0
# Charlotte Hornets   257.0  392.0  3306.0  78340920.0  156689750.0
# Chicago Bulls       288.0  411.0  3284.0  86783378.0  173574722.0

# %%
gk=df2.groupby('Team')
gk.first()
# Out:
#                                          Name  Number Position   Age Height  \
# Team
# Atlanta Hawks                   Kent Bazemore    24.0       SF  26.0    6-5
# Boston Celtics                  Avery Bradley     0.0       PG  25.0    6-2
# Brooklyn Nets                Bojan Bogdanovic    44.0       SG  27.0    6-8
# Charlotte Hornets               Nicolas Batum     5.0       SG  27.0    6-8
# Chicago Bulls                Cameron Bairstow    41.0       PF  25.0    6-9
# Cleveland Cavaliers       Matthew Dellavedova     8.0       PG  25.0    6-4
# Dallas Mavericks              Justin Anderson     1.0       SG  22.0    6-6
# Denver Nuggets                 Darrell Arthur     0.0       PF  28.0    6-9
# Detroit Pistons                  Joel Anthony    50.0        C  33.0    6-9
# Golden State Warriors         Leandro Barbosa    19.0       SG  33.0    6-3
# Houston Rockets                  Trevor Ariza     1.0       SF  30.0    6-8
# ...
